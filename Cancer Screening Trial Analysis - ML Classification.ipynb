# %% [markdown]
# # Cancer dataset

# %% [markdown]
# ## Project Description
#
# **Project Summary: Prostate, Lung, Colorectal, and Ovarian (PLCO) Cancer Screening Trial Analysis** 🩺📊
#
# **Project Description:**
# The Prostate, Lung, Colorectal, and Ovarian (PLCO) Cancer Screening Trial, sponsored by the National Cancer Institute (NCI), aims to assess the risk of developing PLCO cancer. The screening phase concluded in 2006, but data collection continued until 2015. This mini-project focuses on a subset of the dataset with 216 patients, classified as ('C') cancer and ('N') No cancer, featuring 4000 features encompassing gene-related and blood-related information. 🧬💉
#
# **Project Steps:**
#
# 1. **Data Preprocessing:**
#    - Handle missing values ✨
#    - Remove duplicates 🗑️
#    - Visualization 📊
#    - Encoding the Output Data 📊
#    - Checking if the dataset contains any NULL values 🧐
#    - Taking care of outliers 📊🧐
#    - Feature Scaling 📏
#
# 2. **Model Selection:**
#    - PCA with SKLearn (Part A) 📊
#    - PCA with SKLearn (Part B) 📊
#    - ANN Classifier with first 10 PCs (Part C) 🧠
#    - KNN 📊
#    - SVM-RBE 📊
#    - Naive Bayes 📊
#
# 3. **Model Training:**
#    - Split data into training and testing sets 🧩
#    - Train selected models on training data 🚀
#
# 4. **Model Evaluation:**
#    - Evaluate model performance using accuracy metrics 📊
#    - Analyze confusion matrix 📉
#    - Plotting the Learning Curve 📈
#
# 5. **Additional Analysis (if needed):**
#    - Hyperparameter tuning for model optimization ⚙️

# %% [markdown]
# ## Importing the Libraries

# %%
#For basic operations
import numpy as np
import pandas as pd


#For visulauzations
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import seaborn as sns
import plotly.express as px


#Tensorflow
import tensorflow as tf

# %% [markdown]
# ## Importing the Dataset

# %%
dataset = pd.read_csv('Cancer.csv',header=None)

# %% [markdown]
# ## Showing the Dataset in a Table

# %%
pd.DataFrame(dataset)
# Out:
#          0         1         2         3         4         5         6     \
# 0    0.063915  0.033242  0.018484  0.008618  0.035629  0.037925  0.028865
# 1    0.025409  0.051085  0.056305  0.021738  0.027410  0.014914  0.022455
# 2    0.025536  0.036123  0.054195  0.009735  0.027521  0.052255  0.042812
# 3    0.012817  0.029652  0.079290  0.050677  0.039737  0.057713  0.044492
# 4    0.019846 -0.010577 -0.007504  0.019042  0.068786  0.061764  0.039036
# ..        ...       ...       ...       ...       ...       ...       ...
# 211  0.019997  0.002927  0.006809 -0.003585  0.026362  0.026540  0.026112
# 212  0.042346  0.031884  0.049617  0.031419  0.042043  0.033383  0.054695
# 213  0.023558  0.021331  0.016210  0.012324  0.022074  0.029829  0.032624
# 214  0.028351  0.023266  0.004556  0.024095  0.018943  0.025935  0.019066
# 215  0.027428  0.027021  0.015273  0.026199  0.018178  0.022988  0.021955
#
#          7         8         9     ...      3991      3992      3993  \
# ...

# %% [markdown]
# ## A Quick Review of the Data

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Columns: 4001 entries, 0 to 4000
# dtypes: float64(4000), object(1)
# memory usage: 6.6+ MB

# %% [markdown]
# ## Visualization

# %%
print("Dataset shape:")
print ("Dataset shape:{}".format(dataset.shape))
unique_vals = dataset[4000].unique()
print ("Unique values:{}".format(unique_vals))



dataset#print (targets)
#Print (targets[0]) # All Cancer
#print (targets[1]) # All No-Cancer


##### Pie chart##########
labels = ['Cancer', 'No-Cancer']
colors = ['Red', 'Green']
size = dataset[4000].value_counts() # returns a python series (i.e. one dimensional labelled array) 
print ("size: {}".format(size))


explode = [0, 0.1 ]
plt.style.use('seaborn-deep')
plt.rcParams['figure.figsize'] = (7, 7)
plt.pie(size, labels =labels, colors = colors, explode = explode, autopct = "%.2f%%" ,shadow = True)
#plt.axis('off')
plt.title('Target: Cancer or No-Cancer', fontsize = 15)
plt.legend()
plt.show()
# series.plot(x='', y='', kind=“scatter”)
size.plot(kind="bar");
# Out:
# Dataset shape:
# Dataset shape:(216, 4001)
# Unique values:['C' 'N']
# size: C    121
# N     95
# Name: 4000, dtype: int64

# %% [markdown]
# ## Seperate The Input and Output

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
pd.DataFrame(y)
# Out:
#      0
# 0    C
# 1    C
# 2    C
# 3    C
# 4    C
# ..  ..
# 211  N
# 212  N
# 213  N
# 214  N
# 215  N
#
# [216 rows x 1 columns]

# %% [markdown]
# ## Encoding the Output Data

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
pd.DataFrame(y)
# Out:
#      0
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# ..  ..
# 211  1
# 212  1
# 213  1
# 214  1
# 215  1
#
# [216 rows x 1 columns]

# %% [markdown]
# labels:
# - Cancer: 0
#
# - No-Cancer: 1

# %% [markdown]
# ## PCA with SKLearn (Part A)
# "Principal Component Analysis, or PCA, is a dimensionality-reduction method that is often used to reduce the dimensionality of large data sets, by transforming a large set of variables into a smaller one that still contains most of the information in the large set
#
#
# So to sum up, the idea of PCA is simple — reduce the number of variables of a data set, while preserving as much information as possible."
#
# Source: https://builtin.com/data-science/step-step-explanation-principal-component-analysis

# %%
from sklearn.decomposition import PCA
PrinCom=PCA(n_components=216)
PrinCom.fit(X)
Z=PrinCom.transform(X)

# %%
pd.DataFrame(Z)
# Out:
#            0         1         2         3         4         5         6    \
# 0     7.967050 -1.272538 -0.939434 -1.676802  0.467135 -1.865743 -3.123891
# 1     9.232076  0.301563  0.592931 -1.288446  0.132467 -1.776018 -1.495513
# 2    19.916177 -0.481135  3.237053 -5.158392  1.275851 -0.276839 -0.132431
# 3    12.532131 -0.771284  1.664512 -0.986891 -0.540342 -1.906305 -0.498964
# 4    29.609009  9.245273 -0.891703 -4.084310 -3.478759 -1.670141  3.176643
# ..         ...       ...       ...       ...       ...       ...       ...
# 211  -9.371847 -4.630907 -4.549528 -3.466665 -0.167354 -1.254236  0.522350
# 212  -2.911468 -1.058665 -3.164063 -3.331853 -0.914281 -1.735410 -1.410405
# 213  -0.593858 -5.645191 -3.526756 -0.890293 -1.947446  0.336263  0.965317
# 214  -3.906437 -6.615193 -4.353726 -1.998341 -1.630911  0.240236 -0.310490
# 215  -0.150276  2.173768  0.752956  2.359882 -0.201940 -1.740563 -0.260617
#
# ...

# %%
# The first two Principal Components (PC1 and PC2 or Z0 and Z1).
pd.DataFrame(Z[:,0:2])
# Out:
#              0         1
# 0     7.967050 -1.272538
# 1     9.232076  0.301563
# 2    19.916177 -0.481135
# 3    12.532131 -0.771284
# 4    29.609009  9.245273
# ..         ...       ...
# 211  -9.371847 -4.630907
# 212  -2.911468 -1.058665
# 213  -0.593858 -5.645191
# 214  -3.906437 -6.615193
# 215  -0.150276  2.173768
#
# [216 rows x 2 columns]

# %%
# Plotting PC1-PC2 for these 216 patients.
plt.scatter(Z[:,0],Z[:,1],c=y)

# %% [markdown]
# ## PCA with SKLearn (Part B)

# %%
total_sum=0
for i in range(216):
    
    total_sum+=np.var(Z[:,i])
    if i ==9 :
        sum_10PCs=total_sum

percentage=(sum_10PCs/total_sum)*100

print(percentage)
# Out:
# 97.20100144988591

# %% [markdown]
# Using the first ten principal componets ( Z0, Z1, Z2, Z3, Z4, Z5, Z6, Z7, Z8, Z9), 97.2% of the information preserves.

# %% [markdown]
# ## ANN Classifier with first 10 PCs (Part C)

# %% [markdown]
# ### Showing the new Input Data in a Table format

# %%
Z=Z[:,0:10]

# %%
pd.DataFrame(Z)
# Out:
#              0         1         2         3         4         5         6  \
# 0     7.967050 -1.272538 -0.939434 -1.676802  0.467135 -1.865743 -3.123891
# 1     9.232076  0.301563  0.592931 -1.288446  0.132467 -1.776018 -1.495513
# 2    19.916177 -0.481135  3.237053 -5.158392  1.275851 -0.276839 -0.132431
# 3    12.532131 -0.771284  1.664512 -0.986891 -0.540342 -1.906305 -0.498964
# 4    29.609009  9.245273 -0.891703 -4.084310 -3.478759 -1.670141  3.176643
# ..         ...       ...       ...       ...       ...       ...       ...
# 211  -9.371847 -4.630907 -4.549528 -3.466665 -0.167354 -1.254236  0.522350
# 212  -2.911468 -1.058665 -3.164063 -3.331853 -0.914281 -1.735410 -1.410405
# 213  -0.593858 -5.645191 -3.526756 -0.890293 -1.947446  0.336263  0.965317
# 214  -3.906437 -6.615193 -4.353726 -1.998341 -1.630911  0.240236 -0.310490
# 215  -0.150276  2.173768  0.752956  2.359882 -0.201940 -1.740563 -0.260617
#
#             7         8         9
# ...

# %% [markdown]
# ### Showing the output Data in a Table format

# %%
pd.DataFrame(y)
# Out:
#      0
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# ..  ..
# 211  1
# 212  1
# 213  1
# 214  1
# 215  1
#
# [216 rows x 1 columns]

# %% [markdown]
# ### Checking if the dataset contains any NULL values

# %%
dataset.isnull().any().any()
# Out:
# False

# %% [markdown]
# No need to do imputation

# %% [markdown]
# ### Taking care of outliers in Z & y

# %%
# Source 1: https://towardsdatascience.com/local-outlier-factor-lof-algorithm-for-outlier-identification-8efb887d9843
# Source 2: https://towardsdatascience.com/anomaly-detection-with-local-outlier-factor-lof-d91e41df10f2
#Local Outlier Factor (LOF) — Algorithm for outlier identification

from sklearn.neighbors import LocalOutlierFactor
lof = LocalOutlierFactor(contamination=0.01)

# yhat has postive and negative values(i.e +1 & -1).Negative values are outliers 
# and positives inliers

yhat = lof.fit_predict(Z)


# filter outlier values
mask = (yhat != -1)

print("mask shape: ",mask.shape)

Z, y = Z[mask, :], y[mask]
print("Z shape: {}".format(Z.shape))
print("y shape: {}".format (y.shape))

pd.DataFrame(Z)
# Out:
# mask shape:  (216,)
# Z shape: (213, 10)
# y shape: (213,)
#              0         1         2         3         4         5         6  \
# 0     7.967050 -1.272538 -0.939434 -1.676802  0.467135 -1.865743 -3.123891
# 1     9.232076  0.301563  0.592931 -1.288446  0.132467 -1.776018 -1.495513
# 2    19.916177 -0.481135  3.237053 -5.158392  1.275851 -0.276839 -0.132431
# 3    12.532131 -0.771284  1.664512 -0.986891 -0.540342 -1.906305 -0.498964
# 4    29.609009  9.245273 -0.891703 -4.084310 -3.478759 -1.670141  3.176643
# ..         ...       ...       ...       ...       ...       ...       ...
# 208  -9.371847 -4.630907 -4.549528 -3.466665 -0.167354 -1.254236  0.522350
# 209  -2.911468 -1.058665 -3.164063 -3.331853 -0.914281 -1.735410 -1.410405
# 210  -0.593858 -5.645191 -3.526756 -0.890293 -1.947446  0.336263  0.965317
# 211  -3.906437 -6.615193 -4.353726 -1.998341 -1.630911  0.240236 -0.310490
# 212  -0.150276  2.173768  0.752956  2.359882 -0.201940 -1.740563 -0.260617
#
# ...

# %% [markdown]
# ### Splitting the Dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
Z_train, Z_test, y_train, y_test = train_test_split(Z, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ### Feature Scaling

# %%
# Scaling the Z_train using fit_transform () and scaling Z_train using the transform () 

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
Z_train = sc.fit_transform(Z_train)
Z_test = sc.transform(Z_test)

# %% [markdown]
# ### Initializing the ANN

# %%
model= tf.keras.models.Sequential()

# %% [markdown]
# ### Adding the Input Layer

# %%
# Desne: full connection

model.add(tf.keras.layers.Dense(units=10,input_dim=10, activation='relu',kernel_initializer='he_normal'))

# %% [markdown]
# ### Adding the Hidden Layer

# %%
model.add(tf.keras.layers.Dense(units=5, activation='relu',kernel_initializer='he_normal'))
#model.add(tf.keras.layers.Dense(units=2, activation='relu',kernel_initializer='he_normal'))

# %% [markdown]
# ### Adding the Output Layer

# %%
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ### Compiling the ANN

# %%
optimizer = tf.keras.optimizers.Adam()

model.compile(optimizer = optimizer, loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Training the ANN

# %%
#In our call to the fit function, we included reference to a validation dataset. 
#This validation dataset is a portion of the training set not used to fit the model, and is instead used
# to evaluate the performance of the model during training (i.e. during each epoch)
history = \
model.fit(Z_train, y_train, \
             validation_split=0.2, batch_size=25, \
             epochs=155)
# Out:
# Epoch 1/155
# 6/6 [==============================] - 1s 28ms/step - loss: 0.6710 - accuracy: 0.5735 - val_loss: 0.6859 - val_accuracy: 0.6176
# Epoch 2/155
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6425 - accuracy: 0.5735 - val_loss: 0.6661 - val_accuracy: 0.6176
# Epoch 3/155
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6205 - accuracy: 0.5735 - val_loss: 0.6476 - val_accuracy: 0.5882
# Epoch 4/155
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5999 - accuracy: 0.5735 - val_loss: 0.6307 - val_accuracy: 0.5882
# Epoch 5/155
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5838 - accuracy: 0.5735 - val_loss: 0.6184 - val_accuracy: 0.5882
# Epoch 6/155
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5701 - accuracy: 0.5882 - val_loss: 0.6050 - val_accuracy: 0.5882
# Epoch 7/155
# ...

# %% [markdown]
# ### Visualize the model

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 10)                110
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 55
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                60
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 55
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 6
# ...
# Total params: 286
# Trainable params: 286
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Evaluating the Model

# %% [markdown]
# -From an API perspective, this involves calling a function with the holdout dataset and getting a loss and perhaps other metrics that can be reported.
#
#     model.evaluate((Z_test,y_test)
#
# -From an API perspective, you simply call a function to make a prediction of a class label, probability, or numerical value: whatever you designed your model to predict.
#
#
# -Learning curves are a plot of neural network model performance over time, such as calculated at the end of each training epoch.
# Plots of learning curves provide insight into the learning dynamics of the model, such as whether the model is learning well, whether it is underfitting the training dataset, or whether it is overfitting the training dataset.

# %% [markdown]
# #### Prediction on the Test Set

# %%
pd.DataFrame(Z_test)
# Out:
#            0         1         2         3         4         5         6  \
# 0  -1.145851 -1.315038  0.337238  0.248303 -1.279376  0.774766  0.547514
# 1   3.188515  0.561617  1.484426 -2.281210 -0.701367 -0.733353  0.746669
# 2   1.287475  2.492020 -0.920114 -0.433109 -1.743728 -0.688923  0.898556
# 3  -0.909678  0.943383  1.697230  0.798692  1.383115 -0.890028 -0.131173
# 4   1.361314 -0.345760  1.983802  1.650627  1.251326 -1.999050 -2.300571
# 5   0.990013  1.347768 -0.299653  0.855239 -1.361836 -0.562837 -2.003611
# 6   1.051060 -0.263894 -1.860775  2.630039  1.909404  0.125350  1.594109
# 7  -0.898595  0.281572 -0.217756 -0.359110  0.579828 -0.819765  0.526314
# 8   1.675815  2.886588  0.121456 -2.093276 -1.035121  1.064346  1.724005
# 9  -0.261707  1.653961 -0.555150 -0.551262 -1.005064  0.297570 -1.383825
# 10 -0.886576  0.058586 -0.352037 -0.319182  0.520766 -0.201307  0.494500
# 11 -0.393188 -1.486957  0.092119 -0.595239  0.807829 -1.134667 -0.215276
# ...

# %%
y_pred = model.predict(Z_test)
No_Cancer = (y_pred > 0.5)
#Just for quick test: 
print('No Cancer?', No_Cancer[1])
print('No Cancer?', No_Cancer[0])
# Out:
# No Cancer? [False]
# No Cancer? [ True]

# %% [markdown]
# #### Checking the Confusion Matrix and Accuracy Score

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = (y_pred > 0.5) #Classification metrics can't handle a mix of binary and continuous targets, so we change the target (y_pred) to binary, True/False
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[19  1]
#  [ 3 20]]
# 0.9069767441860465

# %%
# Another quick way to check the loss and accuracy
model.evaluate(Z_test,y_test)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4063 - accuracy: 0.9070
# [0.40629541873931885, 0.9069767594337463]

# %% [markdown]
# ###  Plotting the Learning Curve

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Learning Curve')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train','Val'], loc='upper left')

plt.show()

# %% [markdown]
# ##  Other binary ML classifiers

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3) # change n_neighbors; boundary becomes smoother with increasing value of K
knn.fit(Z_train, y_train)
y_pred = knn.predict(Z_test)
KNN_accuracy = np.sum(y_pred==y_test)/len(y_test)
print(KNN_accuracy)
# Out:
# 0.9302325581395349

# %% [markdown]
# ### SVM-RBF

# %%
from sklearn.svm import SVC
svmrbf = SVC(kernel='rbf')
svmrbf.fit(Z_train, y_train)
y_pred = svmrbf.predict(Z_test)
SVM_RBF_accuracy = np.sum(y_pred==y_test)/len(y_test)
print(SVM_RBF_accuracy)
# Out:
# 0.9534883720930233

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb_clf = GaussianNB()
nb_clf.fit(Z_train, y_train)
y_pred = nb_clf.predict(Z_test)
GNB_accuracy = np.sum(y_pred==y_test)/len(y_test)
print(GNB_accuracy)
# Out:
# 0.9069767441860465

# %% [markdown]
# ##  Interpretation of the results

# %% [markdown]
# ANN
#
# -version 1 with epcoh=100 and  batch_size=20; The model was (underfitting) as The training loss continued to decrease until the end of training. The accuracy was 88%
#
#
# -version 2 with epoch =155 and batch_size=25: the model was optimal-fitting (good fit) with an accuracy of 90.6%
#
#
#
# After tuning the hyperparmeters, I found that version 2 is the best ANN model with an accuracy of 90.6%.
#
#
# One observtion to make here is that reducing the number of input variables of the dataset to 10 was easier to explore and visualize and make analyzing the dataset data much easier and faster for the ANN  learning algorithm.
#
#
#
# Finally, since our dataset is not large, it might be better to use a machine learning alogirthm that gives a simialr or better performance, as the case with SVM-RBF with an accuracy of 95.3%.
